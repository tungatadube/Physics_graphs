# %%
% matplotlib inline

# %%
import e

# %%
import springline

# %%
import temperature

# %%
import TEMPLATELINE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c8cd07431be6> in <module>()
# ----> 1 import TEMPLATELINE
#
# ModuleNotFoundError: No module named 'TEMPLATELINE'

# %%
import TEMPLATE_LINE
