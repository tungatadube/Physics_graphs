# %%
import pie_background_radiation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-019f072a8090> in <module>()
# ----> 1 import pie_background_radiation
#
# ~\Desktop\Physics_graphs\pie_background_radiation.py in <module>()
#      28     plt.show()
#      29
# ---> 30 pie_chart('Sources of Background radiation')
#
# ~\Desktop\Physics_graphs\pie_background_radiation.py in pie_chart(title)
#      19
#      20
# ---> 21     pie, text =  plt.pie(fracs, shadow=True, explode=explode)
#      22     plt.title(title, color='blue', fontsize=14)
#      23     plt.axis('equal')
#
# c:\users\user\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, hold, data)
# ...

# %%
exit()

# %%
import pie_background_radiation

# %%
% matplotlib inline

# %%
pie_chart('Sources of Background radiation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-53a1ee1ee0c8> in <module>()
# ----> 1 pie_chart('Sources of Background radiation')
#
# NameError: name 'pie_chart' is not defined

# %%
pie_background_radiation.pie_chart('Sources of Background radiation')

# %%
pie_background_radiation.pie_chart('Sources of Background radiation')

# %%
pie_background_radiation.pie_chart('Sources of Background radiation')

# %%
exit()

# %%
pie_background_radiation.pie_chart('Sources of Background radiation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae6dba113764> in <module>()
# ----> 1 pie_background_radiation.pie_chart('Sources of Background radiation')
#
# NameError: name 'pie_background_radiation' is not defined

# %%
import pie_background_radiation

# %%
exit()

# %%
import pie_background_radiation

# %%
% mat
