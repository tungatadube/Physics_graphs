# %%
% matplotlin inline
# Out:
# UsageError: Line magic function `%matplotlin` not found.

# %%
% matplotlin inline
# Out:
# UsageError: Line magic function `%matplotlin` not found.

# %%
% matplotlib inline

# %%
import radioactive_decay_3

# %%
exit()
